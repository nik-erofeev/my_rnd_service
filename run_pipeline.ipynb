# %% [markdown]
# ### Пример запуска

# %%
from app.services.RAG.local_runner import main

await main()
# Out:
# 2026-01-10 15:40:24 - DEBUG - app.services.RAG.rag_pipeline.utils.prompts.manager - Загружены промпты: ['BaseLLM', 'Classifier', 'Retriever', 'AnswerChecker']
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - 🛠️ Начало построения RAG-графа...
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла DocsCounter...
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла IntentClassifier...
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла RetrieverIntent...
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла Reranker реранкера...
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла проверки ответа (AnswerChecker)
# 2026-01-10 15:40:24 - INFO - app.services.RAG.rag_pipeline.graph.builder - Сборка графа состояний...
# ...

# %% [markdown]
# ### График

# %%
# !pip install ipython
from app.core.config import CONFIG
from app.core.container import DependencyContainer

container = DependencyContainer(config=CONFIG)


# Визуализировать граф
container.graph_builder.get_image_graph()

# Получить StateGraph для отладки
# state_graph = container.graph_builder.get_graph_builder()

# Получить скомпилированный граф
# compiled_graph = container.graph_builder.build()
# Out:
# 2026-01-10 15:40:26 - INFO - app.core.container - 🔧 Создание RAGGraphBuilder...
# 2026-01-10 15:40:26 - INFO - app.core.container - 🔧 Инициализация LLM...
# 2026-01-10 15:40:26 - INFO - app.core.container - ✅ LLM инициализирован
# 2026-01-10 15:40:26 - DEBUG - app.services.RAG.rag_pipeline.utils.prompts.manager - Загружены промпты: ['BaseLLM', 'Classifier', 'Retriever', 'AnswerChecker']
# 2026-01-10 15:40:26 - INFO - app.core.container - ✅ RAGGraphBuilder создан
# 2026-01-10 15:40:26 - INFO - app.services.RAG.rag_pipeline.graph.builder - 🛠️ Начало построения RAG-графа...
# 2026-01-10 15:40:26 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла DocsCounter...
# 2026-01-10 15:40:26 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла IntentClassifier...
# 2026-01-10 15:40:26 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла RetrieverIntent...
# ...
