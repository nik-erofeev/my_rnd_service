# %%
from app.services.RAG.local_runner import main

await main()
# Out:
# 2025-12-26 16:51:11 - DEBUG - app.services.RAG.rag_pipeline.utils.prompts.manager - Загружены промпты: ['BaseLLM', 'Classifier', 'Retriever', 'AnswerChecker']
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - 🛠️ Начало построения RAG-графа...
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла DocsCounter...
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла IntentClassifier...
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла RetrieverIntent...
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла Reranker реранкера...
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Инициализация узла проверки ответа (AnswerChecker)
# 2025-12-26 16:51:11 - INFO - app.services.RAG.rag_pipeline.graph.builder - Сборка графа состояний...
# ...
